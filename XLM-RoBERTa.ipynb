# %%
# %load_ext autoreload
# %autoreload 2

# %%
from transformers import pipeline

model_name = "tsmatz/xlm-roberta-ner-japanese"
classifier = pipeline("token-classification", model=model_name, device="cuda:0")
result = classifier("鈴木は4月の陽気の良い日に、鈴をつけて熊本県の阿蘇山に登った")
print(result)
# Out:
# [{'entity': 'PER', 'score': 0.9993142, 'index': 1, 'word': '▁', 'start': 0, 'end': 1}, {'entity': 'PER', 'score': 0.9993973, 'index': 2, 'word': '鈴', 'start': 0, 'end': 1}, {'entity': 'PER', 'score': 0.9992887, 'index': 3, 'word': '木', 'start': 1, 'end': 2}, {'entity': 'LOC', 'score': 0.9991264, 'index': 14, 'word': '熊本', 'start': 19, 'end': 21}, {'entity': 'LOC', 'score': 0.9980952, 'index': 15, 'word': '県', 'start': 21, 'end': 22}, {'entity': 'LOC', 'score': 0.99906176, 'index': 17, 'word': '阿', 'start': 23, 'end': 24}, {'entity': 'LOC', 'score': 0.9990877, 'index': 18, 'word': '蘇', 'start': 24, 'end': 25}, {'entity': 'LOC', 'score': 0.9983518, 'index': 19, 'word': '山', 'start': 25, 'end': 26}]

# %%
from utils import flatten, get_consecutive_name_entities, partition_words, find_first_non_consecutive_substring
from utils import fix_repeated_chars, find_example_sentences, has_kana, load_config, concat_kanji_rubi, find_rubi, toggle_kana
from utils import parse_gpt_json, remove_common_suffix, extract_ruby_from_epub
from tqdm import tqdm 
import fastapi_poe as fp
from epubparser import main
import re
import os

# %%
api_key = 'gp13DNOpQh8lBHin55kD6_0js__F7n6WfWQOHarr8P0'

# Create an asynchronous function to encapsulate the async for loop
async def get_responses(api_key, messages):
    final_message = ""
    async for partial in fp.get_bot_response(messages=messages, bot_name="GPT-4", api_key=api_key):
        final_message += partial.text
        print(partial.text, end="")
    return final_message

# %%
config = load_config()
epub_files = [os.path.join('output', config['CN_TITLE'], 'input.epub')] 
# epub_files = glob.glob(os.path.join('books/', '**/*.epub'), recursive=True)

book = []
for file in epub_files:
    book += main(file)
book = [concat_kanji_rubi(x) for x in book]
# Out:
# c:\Users\kevin\miniconda3\envs\epub\Lib\site-packages\ebooklib\epub.py:1395: UserWarning: In the future version we will turn default option ignore_ncx to True.
#   warnings.warn('In the future version we will turn default option ignore_ncx to True.')
# c:\Users\kevin\Github\epubtranslator\epubparser.py:19: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(content, "html5lib")
#   0%|          | 0/612 [00:00<?, ?it/s]c:\Users\kevin\Github\epubtranslator\epubparser.py:40: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(item.content.decode("utf-8"), "html5lib")
# 100%|██████████| 612/612 [00:05<00:00, 116.20it/s]

# %%
results = []
for jp_text in tqdm(book):
    results.append(classifier(jp_text))
# Out:
#   0%|          | 7/3704 [00:00<01:59, 30.90it/s]c:\Users\kevin\miniconda3\envs\epub\Lib\site-packages\transformers\pipelines\base.py:1123: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# 100%|██████████| 3704/3704 [01:49<00:00, 33.86it/s]

# %%
entities = {}
ignorable_postfix = ['家の', '様', 'の', 'くん', '家', 'さん', 'と', 'ちゃん', 'っち', '姉', "王女", "先輩", "領", '殿',
                     '連合', '軍', '部隊', '大陸', 'たん', 'が', 'も', 'は', '君', 'ッ']
ignorable_mid = ["王国", "聖国", "帝国", "獣国", "公国", "皇国", '国']
exclusion = ['わたく', 'わたくし', 'きょー', 'きみ', 'アレ', 'テメェ', 
             'わらわ', 'ぼかぁ', 'まんこ', 'カリ', 'おちんぽ', 'メイド', 'オーク', 
             'さん', 'コイツ', 'クリトリス', '日本', 'オーノー', 'アン', 'カミサマ']

### Counting entities, ignoing entities with ignorable postfix and mid
for result in results: 
    for entity in get_consecutive_name_entities(result, score_threshold=0.2):
        if '▁' in entity:
            entity = re.sub(r'▁.*', '', entity)
        if entity in exclusion:
            continue
        flag = False
        for postfix in ignorable_postfix:
            entity_wo = entity[:-len(postfix)]
            if entity.endswith(postfix) and entity_wo in entities:
                if entity in entities:
                    entities[entity_wo] += entities[entity]
                    del entities[entity]
                entities[entity_wo] += 1
                flag = True
                break
        for mid in ignorable_mid:
            if mid in entity:
                entity_wo = entity.split(mid)[0]
                if entity_wo in entities:
                    if entity in entities:
                        entities[entity_wo] += entities[entity]
                        del entities[entity]
                    entities[entity_wo] += 1
                    flag = True
                break
        if flag:
            continue
        if "の" in entity:
            continue
        if entity in entities:
            entities[entity] += 1
        else:
            entities[entity] = 1

# %%
entities.keys()
# Out:
# dict_keys(['レア', 'すえた匂い', 'ケリー', '文化的なコミュニケーション', 'エラーメッセージ', '考察', '使役', '元山猫盗賊団アジト予定地', 'お出かけ', '狩り', '氷狼', 'アリと狼', 'かしこさ', '情報が渋滞してる', '元女王国予定地跡地', 'ウェイン、草原に立つ', 'ブラン・ニュー・ゲーム', '蜾蠃娘子', 'インベントリ', '眷属強化', 'ストラテジー', '心に潜む闇', 'プレイヤーキラー', 'ボーナスステージ', 'システムメッセージ', '開始', '座標認識', '墓', '好', '地。ただし廃墟', '卵とリビング', '第一回大規模イベント開始', '鎧坂さんからは逃げられない', 'ラスボス二段変身ごっこ', '変態だけを殺す機械', '水洗', 'ギル、って呼んでくれ', 'エキシビション', '少し面倒く', '擬態', 'カンファートレント', 'ひさしぶり。ちょっと痩せた?」', 'クエストを受注しました。なお', '世界樹とハイ・エルフ', '選択肢', '魔王誕生', '臨時国会', 'もふ', '侵攻計画', '蹂躙', '深刻な辺境破壊問題', 'ボーナスステージ再び', 'ブ', 'デイウォーカー', 'ブラン', 'ウェイン', 'ウェイン、王都に立つ', 'マルチプル・プレイ', 'リザルト', '魔王覚醒', 'リベンジ', 'ダグラス・オコーネル', 'NPCは侮れない', '今日は廃墟でマラソン大会', '邂逅', 'ヨロイ・ザ・カサン', '公式SNS', '置き土産', 'コネート', '再会', 'アルフ・ライラ・ワ・ライラ', 'ライラ', 'じゃあいい', 'ばか', '姉妹', 'と思ったらコレだよ', 'オーラル革命', 'ダンジョン・コンバージョン', '巣立ち', '新しい朝がきた', 'ネコババ', '説明好きなとことか', '外部顧問', 'すみませんフレに呼ばれますね^^', '火山遠征', 'エルダーロックゴーレム', '神託', '邪道をゆく者', '選考対象外', '限定転移サービス実装', 'ダンログ評価☆3', 'エルフ', '3秒ルール', '早速悪用される新サービス', 'なかまをよんだ!」', 'しかしだれもこなかった', 'プレイヤーズクラン', '大モグラ', '変態女王', 'エルンタール', '報連相、ヨシ', '掌握', '差別化', '二重召喚', 'ゴルフクラブ', '初回特典', '偽造身分', 'ネクロリバイバル', 'バンブ', 'スタンド・バイ・ミー', 'SNS', '大いなる災い', 'ブラック企業', 'ブラン時空', 'スケリェットギドラ', '風評被害', 'ポートリー王ウスターシェ', 'ウルル・インパクト', '食糧は現地調達', 'やっぱり寂しいんじゃん', '直線、回転、流星剣', 'ウスターシェ', '地殻変動', 'アンフィスバエナ', '植民地', '天使襲来', '清らかな心臓', '自然回復', 'じゃれ合い', '邪王誕生', '躾', 'アダマンレギオン', '貴族と平民', 'ラ・ピュセル・ドウェルス', '氷で殴れば人は死ぬ', '観光', '颯爽登場!」', 'ヒーロー、起つ', 'アルケム・エクストラクタ', '特性追加', '災厄3体融合', 'アルティメット魔王', '蛇王覚醒', '影月とかそういう', '服', 'てるだろ。正装を', 'ヨ', '第六災厄', '呪いはタイミングを逃さない', '第六災厄VS第七災厄', 'あっ!', 'レディーレ・プラエテリトゥム', '隣に立つために', 'アブハング湿原', '溜まっていくレポート課題', '復活', 'ばちくそ怪しいNPC', '目で殺す', 'モニカ', '協力者', '大天使討伐', 'ユスティース', 'サービス', '大きいお友達', 'マグナメルム', 'ヒデ', '笑顔', '闇に堕ちた者たち', 'ジャネット矢坂', '非公式SNS', '暗躍する者たち', '墜ちた天空城', 'アップデート', 'メルヘン伯爵', '姫プレイ', '自然に対する傲慢さ', '悪事と経済', '遺跡ダンジョン', '遺跡発掘調査隊', 'ダンジョンとそれ以外', '動きがつくとかっこよく見える', '祭壇', '落下ダメージ小', '遺跡牧場', 'わるだくみ', '盗賊紳士', 'ヨーイチ', '環境適応', 'コバルトブルー', '地味だが堅実', 'UMA', '前が見えない', 'ウロボロス', '小悪魔', '中悪魔', '大悪魔', 'あ、ツレが払いますんで', '愚かな男', 'よく煮た性格', '主人公はつらいよ', '空中庭園アウラケルサス', '選択死', 'クロード', '幼気な祖母', '信念を貫く決意', '来客', '後出しジャンケン', 'じる', '生まれてきた意味を知る', '今世界', '一番', 'たくない席', '寄生虫', 'お世話になりました', '演技派女優', 'ジャネット', '馬と白衣と黒装束', '遊んでるわけでは', 'むせる', '集結', '友人は選んだほうが', '時には悪くない負け方', 'わかりて', '円卓会食', '予期せぬ事態', '俺', '大陸大戦', '特別報酬', '真祖・ノウェム', 'マグナメルム・何とか', '正しき道を行く者', 'お前が救世主になるんだよ', '断', '舗装された坂道', '第三騎士団長', 'ロイク', '食べたらあかんやつ', 'さんをつけろよ', 'クエスト報酬', '聖堂騎士団', '序列一位', '二股説', '調子', 'バーグラー共和国', 'ク', 'ただしお前は別だ', 'コミュニケーション術', 'おっさん', '意地悪', '残り、4つ', 'ジャ...ネットやさか', 'ウェルス国王、ジェローム', '聖戦勃発', '降臨', 'ゲーム', '待ち合わせって何かフレンド', 'い', 'サンドバッグ', '誰が変態ですか', 'アマテイン', '最近わかった新事実', '暗殺依頼', 'エルネスト', '幻獣王誕生', 'アンブロシウス', '既視感', 'バッドエンドルート', '上機嫌', '憤怒と悲嘆', 'お、お、おか、おか', 'るまで回せば実', '確定', '少しずつでも大陸をさっぱりさせんとな', 'ミニマム癒し系', '地味だけど、地味', 'なかった', '主君元気で留守', 'いい', '非同期対戦サービス稼働テスト', '注文', 'と思ったんだけどね', '森エッティ', '実質無限', '握手会かな', 'BHSCTCG', '文字化け', 'うわ来た!', '渚おとめちっく', 'きゃっ', 'ぱしゃぱしゃ', '子ダヌキ', 'ダイナミック庭仕事', 'リヴァイアサン', 'ギリギリ大成功', 'こさえる', 'アウトドアスタイル', '完全無欠', 'を見せたくて仕方がない', 'デ', 'トな色', '自分で行け', '同志を求めて', '海風は髭がごわつく', 'ボス', '古馴染', 'ディアス', 'ブラン無双', 'こちら相席よろしいですか?', '危険な空気', 'ケラ・マレフィクス', 'くと遠ざかる。人間関係は蜃気楼', 'お裾分けされた幸せ', 'か', '前から行くって言ってたし', 'フード', '脱ぐけど猫はかぶる', '降石確率30%', 'ミッション・インベイジョン', 'する', 'イービルユーモア', 'メルキオレ・デ・サンクティス', '代償が重すぎる', '挟まる女', '浜辺で焚き火', '鎧獣騎', '交わした笑顔', 'ぎりぎりマシな方', '例外は認めない', '孫請け', 'ライバルに差をつけろ', '落とし所', '邪であるということ', '天に輝く七つ星', '青空テラスって二番煎じでは', 'いやらしい', '声可愛かったからスか?', '期待を込めて星3つです', '得力', '、合流、新党', '廃都争奪戦', '伝説はファンタジー', '義を見てせざるは', '毒されている', 'マーレ', '貿易船団出港', '漂流者', '詭弁', '餌', '大感謝祭', '二刀流', '死を食らう鷲', '湿原に棲む狼', 'となるも', 'となるなかれ', 'ニコイチ', '同窓会', '反動', '者', 'ブランと海', '水', 'え', 'れ', '遍く世界に', '城塞都市', 'エラ過呼吸', '西方大陸ぶらり旅', '食人植物', 'ウルスス、お前もか', 'アドリブ', 'ガスパール', 'カッコつけマン', 'ジーク', '明日やろうは', '持て余す', '積み上がる罪科', 'INT電話', '意外な才能', '生まれつき', 'まごころ', 'デリカシーがたりない', 'クリスタルウォール', 'ごった煮', 'なんでじゃ', '外来種', '門番', 'ダイレクトマーケティング', '残滓', '拳で語る系女子', '開幕', '足切り', '初戦からクライマックス', '初日終了', 'メリサンド', '逆効果', 'リ・リベンジ', '姫とエルフと下僕と骨と', 'バーガンディ', '正義VS悪', 'ドリンクバー', '得 ...

# %%
# full_text = '\n'.join(book)
# # rubi = find_rubi(entities, full_text.replace('(', '（').replace(')', '）'))
# rubi = find_rubi(entities, full_text)
rubi = extract_ruby_from_epub(epub_files[0])
rubi
# Out:
# {'す': '空',
#  'ライフポイント': 'ＬＰ',
#  'や': '飲',
#  'イコール': '＝',
#  'マナポイント': 'ＭＰ',
#  '・': '妹',
#  'はくま': '白魔',
#  'ぎんか': '銀花',
#  'なめ': '鞣',
#  '再ログイン': 'リログ',
#  'グォレンダァ': '５連打',
#  'さかい': '境',
#  'スガル': '蜾蠃',
#  'かぶり': '頭',
#  'プレイヤーキラー': 'ＰＫ',
#  'ひとけ': '人気',
#  'スクワイア・ゾンビ': '吸血鬼の従者',
#  'レヴナント': '意志ある死者',
#  'レッサーヴァンパイア': '下級吸血鬼',
#  'もてな': '饗',
#  '眠っ': 'ログアウトし',
#  'やじり': '鏃',
#  'かたびら': '帷子',
#  'ふがし': '麩菓子',
#  'すさ': '退',
#  'いころ': '射殺',
#  'ストイック': '禁欲的',
#  'つつもたせ': '美人局',
#  'もや': '靄',
#  '生命力': 'ＬＰ',
#  'スパルトイ': '蒔かれた者',
#  'ま': '蒔',
#  'ぜんしん': '漸進',
#  'おもんぱか': '慮',
#  '経験値': '命',
#  'ログアウトして': '寝て',
#  'しつら': '設',
#  'むくろ': '骸',
#  '我が家': 'リーベ大森林',
#  'かえ': '反',
#  'かげ': '翳',
#  'にぶ': '鈍',
#  'よ': '撚',
#  'にかわ': '膠',
#  'みなぎ': '漲',
#  'トゥルーヴァンパイア': '真祖吸血鬼',
#  'たまわ': '賜',
#  'ふかん': '俯瞰',
#  'はびこ': '蔓延',
#  'センチュリオン': '百卒長',
#  'すうせい': '趨勢',
#  'ね': '睨',
#  'ミドル・ヒール': '中回復',
#  'リジェネレーション': '再生',
#  'エリア・リトルヒール': '範囲小回復',
#  'すく': '掬',
#  'しゃく': '癪',
#  'クリティカル': 'ヘッドショット',
#  'あった': '暖',
#  'アーティファクト': '秘遺物',
#  'はま': '嵌',
#  'かせ': '枷',
#  'まみ': '見',
#  'みまか': '身罷',
#  'さが': '性',
#  'イモータルルーラー': '不死者の王',
#  'しい': '弑',
#  'しらみつぶ': '虱潰',
#  'そのようなこと': '疲労を無視して駆け足',
#  'ログアウトし': '眠っ',
#  'か': '彼',
#  'これ': '『隠伏』',
#  'ライラ': '■■■',
#  'レアちゃん': '■■■',
#  'グレーター': '上級',
#  'ヴァンパイア': '吸血鬼',
#  'アバター': '人',
#  'てい': '体',
#  'スカウト': '斥候',
#  'こな': '熟',
#  '地元': 'ポートリー',
#  'やぶさ': '吝',
#  'バロネス': '男爵',
#  'ドラゴントゥース': '竜の牙',
#  'なに': '何',
#  '精神力': 'ＭＮＤ',
#  'みな': '見做',
#  'ひとかたまり': '一塊',
#  'かね': '予',
#  'アンダーカバー': '身分偽装',
#  'まねる': '真似ぶ',
#  'なますぎ': '膾切',
#  'けち': '吝嗇',
#  'こた': '堪',
#  'ことわり': '理',
#  'Ars longa, vita brevis.': '技術は長く、人生は短い',
#  'むしゃどくろ': '武者髑髏',
#  'ドラゴン・トゥース': '竜の牙',
#  'はい': '入',
#  'ハイ・ヒール': '大回復',
#  'わか': '別',
#  'かかと': '踵',
#  'イモータル・ルーラー': '不死者の王',
#  'なまく': '鈍',
#  'そび': '聳',
#  'さかのぼ': '遡',
#  'モラトリアム': '猶予期間',
#  'きか': '麾下',
#  'なりわい': '生業',
#  'しせい': '市井',
#  'かか': '罹',
#  'ひげ': '鬚',
#  'よこしま': '邪',
#  '協力': 'Co-op',
#  'くく': '括',
#  'あらかじ': '予',
#  'がた': '難',
#  'イキ': '粋',
#  'あ': '充',
#  'エヌ': 'ｎ',
#  'ラ・ピュセル・ドウェルス': 'ウェルスの聖女',
#  'ヒヒ': '狒狒',
#  'しょうじょう': '猩猩',
#  'あぎと': '顎門',
#  'そそのか': '唆',
#  'ほんにん': 'アビゴル',
#  'くだん': '件',
#  'もたら': '齎',
#  'カウンテス': '伯爵級',
#  'マーシャネス': '侯爵級',
#  'ダッチェス': '公爵',
#  'しんさん': '心算',
#  'いけす': '生簀',
#  'ゲーム': '真の戦い',
#  'うんか': '雲霞',
#  'ひら': '開',
#  'わりふ': '割符',
#  'しんしゃく': '斟酌',
#  'なにがし': '何某',
#  'Multa docet fames.': '飢えは多くのことを教える',
#  'Animo imperabit sapiens,stultus serviet.': '賢者は心を支配し、愚者は隷属する',
#  'あんきょ': '暗渠',
#  '虐殺': 'ジェノサイド',
#  'つたな': '拙',
#  'レスレクティオ': '復活',
#  'ロック': '保護',
#  'ワールドボス': '災厄',
#  '森エッティ教授': '検証班の長老',
#  'ゴールデンランニング': '『縮地』での高速移動',
#  'おもはゆ': '面映',
#  'たぐい': '類',
#  'つまび': '詳',
#  'はばか': '憚',
#  'おおむ': '概',
#  'へりくだ': '謙',
#  'ナイツ・プラウス': '騎士の力',
#  'はらわた': '腸',
#  '九番目': 'ノウェム',
#  'ひとかど': '一角',
#  'いそ': '磯',
#  'ぎょしゃ': '御者',
#  'いち': '市',
#  'とし': '歳',
#  'たやす': '容易',
#  'ほふ': '屠',
#  'よう': '杳',
#  'こがね': '黄金',
#  'くわ': '鍬',
#  'こと': '殊',
#  'ほか': '外',
#  'ことごと': '尽',
#  'そんたく': '忖度',
#  'あらわ': '顕',
#  'わたし': '災厄',
#  'レタリス': '致死',
#  'ふんまん': '憤懣',
#  'うなが': '促',
#  'なかだる': '中弛',
#  'ログアウト': '野営',
#  'しらふ': '素面',
#  'きず': '瑕',
#  'もり': '守',
#  'むご': '惨',
#  'したた': '強',
#  'はか': '量',
#  'きりすてごめん': '斬捨御免',
#  'じぶん': '第七災厄',
#  'ドラマ': '映像作品',
#  'おもね': '阿',
#  'しいぎゃく': '弑逆',
#  'うえん': '迂遠',
#  '一睡も': 'ログアウト',
#  'しらみ': '虱',
#  '姉': 'ライラ',
#  '悪役サイド': 'わたしたち寄り',
#  'プレイング': '生活',
#  'ナフサク': '菜富作',
#  'うち': '家',
#  'しんがり': '殿',
#  'ワード': '字面',
#  'こうがい': '蝗害',
#  'いなご': '蝗',
#  'おぼ': '思',
#  'ふるい': '篩',
#  '返り討ちに': 'ＰＫＫ',
#  'いさか': '諍',
#  'せんだっ': '先達',
#  'わざもの': '業物',
#  'うくろ': '鵜黒',
#  'はさみ': '鋏',
#  'ひ': '轢',
#  'いと': '厭',
#  'つま': '摘',
#  'きゆう': '杞憂',
#  'ゆえん': '所以',
#  'は': '捌',
#  'やっこ': '奴',
#  'あやま': '過',
#  '自分の街': 'ウェルス',
#  'いたぶ': '甚振',
#  '転売': '中古品の流通',
#  'すいか': '誰何',
#  'じえいむず': '慈英難',
#  'ぎまん': '欺瞞',
#  'ようりつ': '擁立',
#  'いわしろ': '岩城',
#  'こうきょ': '薨去',
#  'トゥルー': '真祖',
#  'たもと': '袂',
#  'すが': '縋',
#  'おか': '侵',
#  'あつれき': '軋轢',
#  'せん': '先',
#  'さなか': '最中',
#  'うそぶ': '嘯',
#  'めっ': '滅',
#  'バック': '後衛',
#  'うんちく': '蘊蓄',
#  'そうそう': '早々',
#  'そうぞう': '騒々',
#  'なら': '均',
#  'も': '守',
#  'もっか': '目下',
#  'ハセラたち': '聖女原理派',
#  'みたび': '三度',
#  'こだわ': '拘',
#  'はつらつ': '溌剌',
#  'カギ': '精霊王の血管',
#  'ためら': '躊躇',
#  'ど': '退',
#  'あいあらそ': '相争',
#  'さ': '割',
#  'とうとう': '滔々',
#  'こたび': '此度',
#  'だね': '胤',
#  'つて': '伝手',
#  'たまもの': '賜物',
#  'ささ': '捧',
#  'こうはい': '光背',
#  'びゃくごう': '白毫',
#  'と': '摂',
#  'ミドルヒール': '中回復',
#  'じくじ': '忸怩',
#  'きんこじ': '緊箍児',
#  'やさ': '易',
#  'い': '往',
#  'ほこら': '祠',
#  'いとま': '暇',
#  'もと': '悖',
#  'さか': '盛',
#  'すべ': '術',
#  'あだな': '仇為',
#  'こっけい': '滑稽',
#  'たてがみ': '鬣',
#  'いびつ': '歪',
#  'たばか': '謀',
#  'さず': '授',
#  'つつが': '恙',
#  'くすぶ': '燻',
#  '本人': '教授',
#  'しょうしゃ': '瀟洒',
#  'しょうしゃく': '陞爵',
#  'あきな': '商',
#  'はん': '飯',
#  'まつろ': '服',
#  'おもてめん': '表面',
#  'めこぼ': '目溢',
#  'リソース': 'ゲーム情報',
#  'システム': '世界',
#  'いざな': '誘',
#  'そう': '艘',
#  'から': '辛',
#  'ＳＴＲ強化': '力よ',
#  'ＩＮＴ強化': '魔よ',
#  'ＡＧＩ強化': '疾く',
#  'ＭＮＤ強化': '恐れよ',
#  'ＶＩＴ強化': '肉体',
#  'ＤＥＸ強化': '業よ',
#  'まれ': '稀',
#  'かいだいむそう': '海内無双',
#  'かどわ': '拐',
#  '魔アタ': '魔法職アタッカー',
#  'つ': '尾',
#  'ＭＰＣ': 'モンスタープレイヤーズクラン',
#  '相手': '餌',
#  'つまづ': '躓',
#  'コミュニスト': '共産主義者',
#  'おおあまおおい': '大雨覆',
#  'カタストロフ': '天変地異',
#  'ひょう': '雹',
#  'ぐふう': '颶風',
#  'マツド': '松戸',
#  'ずさん': '杜撰',
#  'つまず': '躓',
#  'あと': '後',
#  'うらさび': '心寂',
#  'ふた': '蓋',
#  'よりこ': '寄子',
#  'よりおや': '寄親',
#  'かしず': '傅',
#  'ほとり': '畔',
#  'かいしょうさんさ': '海嘯三叉',
#  'いちば': '市場',
#  'よし': '誼',
#  'ジンゴイズム': '好戦主義',
#  'ふる': '篩',
#  'げん': '験',
#  'きらめ': '煌',
#  'あお': '呷',
#  'はな': '放',
#  'そとづら': '外面',
#  'しめなわ': '注連縄',
#  'いまし': '戒',
#  'わけみ': '分身',
#  'へいげい': '睥睨',
#  'レスレ': '復',
#  'サマ': '様',
#  'なり': '形',
#  'だいたい': '代替',
#  'き': '帰',
#  'うっそう': '欝蒼',
#  'ＭＩＡ': '作戦行動中行方不明',
#  'ホツ': '解',
#  'じじい': '爺',
#  'けお': '気圧',
#  'くさ': '臭',
#  'にお': '臭',
#  'ジー': 'Ｇ',
#  'じい': '爺',
#  '賢さ': 'ＩＮＴ',
#  'ほつ': '解',
#  'おもて': '面',
#  'とうと': '貴',
#  'ほう': '方',
#  'やさか': '矢坂',
#  'くじ': '久慈',
#  'つばくろ': '燕',
#  'きら': '吉良',
#  '勧誘する': 'ひっかける',
#  'きえん': '気炎',
#  'くに': '邦',
#  'そ': '其',
#  'てこず': '手子摺',
#  '営業活動': 'アウトバウンド',
#  'くつろ': '寛',
#  'ごう': '業',
#  'たい': '平',
#  'こじ': '拗',
#  'てきめん': '覿面',
#  'かんば': '芳',
#  'ルーアッハ': '神の息吹',
#  'つくろ': '繕',
#  'あまね': '遍',
#  'けんぺいりつ': '建蔽率',
#  'けそう': '懸想',
#  'お': '追',
#  'ひた': '浸',
#  'ず': '摺',
#  'ふしん': '普請',
#  'あいだ': '間',
#  'おり': '折',
#  'ふん': '糞',
#  'プレイヤー': '異邦人',
#  'よそ': '他所',
#  'あつら': '誂',
#  'あかつき': '暁',
#  'がわ': '側',
#  'キモ': '肝',
#  'くたび': '草臥',
#  'ことわざ': '諺',
#  'せま': '狭',
#  'たわごと': '戯言',
#  'モンスタープレイヤーズ': 'ＭＰ',
#  'ブラン': '容疑者Ｂ',
#  'が': '我',
#  'なま': '生',
#  'あいたい': '相対',
#  'へ': '圧',
#  'かわ': '躱',
#  'せこ': '勢子',
#  'かし': '下賜',
#  'せいよんしゃくだま': '聖四灼玉',
#  'あいまみ': '相見',
#  'そぶ': '素振',
#  'おもちゃ': '鎧獣騎',
#  'ふたりめ': '二発目',
#  'しこくしょく': '紫黒色',
#  'ダンス・マカブル': '死の舞踏',
#  'あられ': '霰',
#  'ＬＰ': '生命力',
#  'ＶＩＴ': '体力',
#  'クー・デ・グレイス': '慈悲の一撃',
#  '名前': 'ナンバー',
#  'Ars longa,': '技術は長く',
#  'vita ': '、人生',
#  'brevis.': 'は短い',
#  'ただ': '爛',
#  'ねぐら': '塒',
#  'アタッカー': 'ＤＰＳ',
#  'いただき': '頂',
#  'おおやけ': '公',
#  'わざわい': '禍',
#  'うず': '渦',
#  'うつつ': '現',
#  'たお': '嫋',
#  'なめろう': '挽き肉',
#  'たちわる': '質悪',
#  'きずもの': '瑕物',
#  'イベント': '決戦',
#  'ひび': '罅',
#  'オウゴンギンチャク': '黄金巾着',
#  'みき': '幹',
#  'なんびと': '何人',
#  'かくらん': '攪乱',
#  'うが': '穿',
#  'えぐ': '抉',
#  'く': '臭',
#  'のき': '軒',
#  'よしみ': '誼',
#  'ファーストアタック': '一番槍',
#  '囮役': '回避タンク',
#  '２人': '２枚',
#  'うつ': '伝染',
#  'みずかめ': '水甕',
#  'ル―アッハ': '神の息吹',
#  'ひときわ': '一際',
#  'Sic itur ad astra.': 'こうして人は天に昇る',
#  'ネメシス・アドラステイア': '遁れえぬ神罰',
#  'あか': '赫',
#  'さんさん': '燦々'}

# %%
rubi = {k: v for k, v in rubi.items() if not has_kana(v) and has_kana(k)}
rubi
# Out:
# {'す': '空',
#  'ライフポイント': 'ＬＰ',
#  'や': '飲',
#  'イコール': '＝',
#  'マナポイント': 'ＭＰ',
#  'はくま': '白魔',
#  'ぎんか': '銀花',
#  'なめ': '鞣',
#  'グォレンダァ': '５連打',
#  'さかい': '境',
#  'スガル': '蜾蠃',
#  'かぶり': '頭',
#  'プレイヤーキラー': 'ＰＫ',
#  'ひとけ': '人気',
#  'レッサーヴァンパイア': '下級吸血鬼',
#  'もてな': '饗',
#  'やじり': '鏃',
#  'かたびら': '帷子',
#  'ふがし': '麩菓子',
#  'すさ': '退',
#  'いころ': '射殺',
#  'ストイック': '禁欲的',
#  'つつもたせ': '美人局',
#  'もや': '靄',
#  'ま': '蒔',
#  'ぜんしん': '漸進',
#  'おもんぱか': '慮',
#  'しつら': '設',
#  'むくろ': '骸',
#  'かえ': '反',
#  'かげ': '翳',
#  'にぶ': '鈍',
#  'よ': '撚',
#  'にかわ': '膠',
#  'みなぎ': '漲',
#  'トゥルーヴァンパイア': '真祖吸血鬼',
#  'たまわ': '賜',
#  'ふかん': '俯瞰',
#  'はびこ': '蔓延',
#  'センチュリオン': '百卒長',
#  'すうせい': '趨勢',
#  'ね': '睨',
#  'ミドル・ヒール': '中回復',
#  'リジェネレーション': '再生',
#  'エリア・リトルヒール': '範囲小回復',
#  'すく': '掬',
#  'しゃく': '癪',
#  'あった': '暖',
#  'アーティファクト': '秘遺物',
#  'はま': '嵌',
#  'かせ': '枷',
#  'まみ': '見',
#  'みまか': '身罷',
#  'さが': '性',
#  'しい': '弑',
#  'しらみつぶ': '虱潰',
#  'か': '彼',
#  'これ': '『隠伏』',
#  'ライラ': '■■■',
#  'レアちゃん': '■■■',
#  'グレーター': '上級',
#  'ヴァンパイア': '吸血鬼',
#  'アバター': '人',
#  'てい': '体',
#  'スカウト': '斥候',
#  'こな': '熟',
#  'やぶさ': '吝',
#  'バロネス': '男爵',
#  'なに': '何',
#  'みな': '見做',
#  'ひとかたまり': '一塊',
#  'かね': '予',
#  'アンダーカバー': '身分偽装',
#  'なますぎ': '膾切',
#  'けち': '吝嗇',
#  'こた': '堪',
#  'ことわり': '理',
#  'むしゃどくろ': '武者髑髏',
#  'はい': '入',
#  'ハイ・ヒール': '大回復',
#  'わか': '別',
#  'かかと': '踵',
#  'なまく': '鈍',
#  'そび': '聳',
#  'さかのぼ': '遡',
#  'モラトリアム': '猶予期間',
#  'きか': '麾下',
#  'なりわい': '生業',
#  'しせい': '市井',
#  'かか': '罹',
#  'ひげ': '鬚',
#  'よこしま': '邪',
#  'くく': '括',
#  'あらかじ': '予',
#  'がた': '難',
#  'イキ': '粋',
#  'あ': '充',
#  'エヌ': 'ｎ',
#  'ヒヒ': '狒狒',
#  'しょうじょう': '猩猩',
#  'あぎと': '顎門',
#  'そそのか': '唆',
#  'くだん': '件',
#  'もたら': '齎',
#  'カウンテス': '伯爵級',
#  'マーシャネス': '侯爵級',
#  'ダッチェス': '公爵',
#  'しんさん': '心算',
#  'いけす': '生簀',
#  'うんか': '雲霞',
#  'ひら': '開',
#  'わりふ': '割符',
#  'しんしゃく': '斟酌',
#  'なにがし': '何某',
#  'あんきょ': '暗渠',
#  'つたな': '拙',
#  'レスレクティオ': '復活',
#  'ロック': '保護',
#  'ワールドボス': '災厄',
#  'おもはゆ': '面映',
#  'たぐい': '類',
#  'つまび': '詳',
#  'はばか': '憚',
#  'おおむ': '概',
#  'へりくだ': '謙',
#  'はらわた': '腸',
#  'ひとかど': '一角',
#  'いそ': '磯',
#  'ぎょしゃ': '御者',
#  'いち': '市',
#  'とし': '歳',
#  'たやす': '容易',
#  'ほふ': '屠',
#  'よう': '杳',
#  'こがね': '黄金',
#  'くわ': '鍬',
#  'こと': '殊',
#  'ほか': '外',
#  'ことごと': '尽',
#  'そんたく': '忖度',
#  'あらわ': '顕',
#  'わたし': '災厄',
#  'レタリス': '致死',
#  'ふんまん': '憤懣',
#  'うなが': '促',
#  'なかだる': '中弛',
#  'ログアウト': '野営',
#  'しらふ': '素面',
#  'きず': '瑕',
#  'もり': '守',
#  'むご': '惨',
#  'したた': '強',
#  'はか': '量',
#  'きりすてごめん': '斬捨御免',
#  'じぶん': '第七災厄',
#  'ドラマ': '映像作品',
#  'おもね': '阿',
#  'しいぎゃく': '弑逆',
#  'うえん': '迂遠',
#  'しらみ': '虱',
#  'プレイング': '生活',
#  'ナフサク': '菜富作',
#  'うち': '家',
#  'しんがり': '殿',
#  'ワード': '字面',
#  'こうがい': '蝗害',
#  'いなご': '蝗',
#  'おぼ': '思',
#  'ふるい': '篩',
#  '返り討ちに': 'ＰＫＫ',
#  'いさか': '諍',
#  'せんだっ': '先達',
#  'わざもの': '業物',
#  'うくろ': '鵜黒',
#  'はさみ': '鋏',
#  'ひ': '轢',
#  'いと': '厭',
#  'つま': '摘',
#  'きゆう': '杞憂',
#  'ゆえん': '所以',
#  'は': '捌',
#  'やっこ': '奴',
#  'あやま': '過',
#  'いたぶ': '甚振',
#  'すいか': '誰何',
#  'じえいむず': '慈英難',
#  'ぎまん': '欺瞞',
#  'ようりつ': '擁立',
#  'いわしろ': '岩城',
#  'こうきょ': '薨去',
#  'トゥルー': '真祖',
#  'たもと': '袂',
#  'すが': '縋',
#  'おか': '侵',
#  'あつれき': '軋轢',
#  'せん': '先',
#  'さなか': '最中',
#  'うそぶ': '嘯',
#  'めっ': '滅',
#  'バック': '後衛',
#  'うんちく': '蘊蓄',
#  'そうそう': '早々',
#  'そうぞう': '騒々',
#  'なら': '均',
#  'も': '守',
#  'もっか': '目下',
#  'ハセラたち': '聖女原理派',
#  'みたび': '三度',
#  'こだわ': '拘',
#  'はつらつ': '溌剌',
#  'ためら': '躊躇',
#  'ど': '退',
#  'あいあらそ': '相争',
#  'さ': '割',
#  'とうとう': '滔々',
#  'こたび': '此度',
#  'だね': '胤',
#  'つて': '伝手',
#  'たまもの': '賜物',
#  'ささ': '捧',
#  'こうはい': '光背',
#  'びゃくごう': '白毫',
#  'と': '摂',
#  'ミドルヒール': '中回復',
#  'じくじ': '忸怩',
#  'きんこじ': '緊箍児',
#  'やさ': '易',
#  'い': '往',
#  'ほこら': '祠',
#  'いとま': '暇',
#  'もと': '悖',
#  'さか': '盛',
#  'すべ': '術',
#  'あだな': '仇為',
#  'こっけい': '滑稽',
#  'たてがみ': '鬣',
#  'いびつ': '歪',
#  'たばか': '謀',
#  'さず': '授',
#  'つつが': '恙',
#  'くすぶ': '燻',
#  'しょうしゃ': '瀟洒',
#  'しょうしゃく': '陞爵',
#  'あきな': '商',
#  'はん': '飯',
#  'まつろ': '服',
#  'おもてめん': '表面',
#  'めこぼ': '目溢',
#  'システム': '世界',
#  'いざな': '誘',
#  'そう': '艘',
#  'から': '辛',
#  'まれ': '稀',
#  'かいだいむそう': '海内無双',
#  'かどわ': '拐',
#  'つ': '尾',
#  'つまづ': '躓',
#  'コミュニスト': '共産主義者',
#  'おおあまおおい': '大雨覆',
#  'カタストロフ': '天変地異',
#  'ひょう': '雹',
#  'ぐふう': '颶風',
#  'マツド': '松戸',
#  'ずさん': '杜撰',
#  'つまず': '躓',
#  'あと': '後',
#  'うらさび': '心寂',
#  'ふた': '蓋',
#  'よりこ': '寄子',
#  'よりおや': '寄親',
#  'かしず': '傅',
#  'ほとり': '畔',
#  'かいしょうさんさ': '海嘯三叉',
#  'いちば': '市場',
#  'よし': '誼',
#  'ジンゴイズム': '好戦主義',
#  'ふる': '篩',
#  'げん': '験',
#  'きらめ': '煌',
#  'あお': '呷',
#  'はな': '放',
#  'そとづら': '外面',
#  'しめなわ': '注連縄',
#  'いまし': '戒',
#  'わけみ': '分身',
#  'へいげい': '睥睨',
#  'レスレ': '復',
#  'サマ': '様',
#  'なり': '形',
#  'だいたい': '代替',
#  'き': '帰',
#  'うっそう': '欝蒼',
#  'ホツ': '解',
#  'じじい': '爺',
#  'けお': '気圧',
#  'くさ': '臭',
#  'にお': '臭',
#  'ジー': 'Ｇ',
#  'じい': '爺',
#  '賢さ': 'ＩＮＴ',
#  'ほつ': '解',
#  'おもて': '面',
#  'とうと': '貴',
#  'ほう': '方',
#  'やさか': '矢坂',
#  'くじ': '久慈',
#  'つばくろ': '燕',
#  'きら': '吉良',
#  'きえん': '気炎',
#  'くに': '邦',
#  'そ': '其',
#  'てこず': '手子摺',
#  'くつろ': '寛',
#  'ごう': '業',
#  'たい': '平',
#  'こじ': '拗',
#  'てきめん': '覿面',
#  'かんば': '芳',
#  'つくろ': '繕',
#  'あまね': '遍',
#  'けんぺいりつ': '建蔽率',
#  'けそう': '懸想',
#  'お': '追',
#  'ひた': '浸',
#  'ず': '摺',
#  'ふしん': '普請',
#  'あいだ': '間',
#  'おり': '折',
#  'ふん': '糞',
#  'プレイヤー': '異邦人',
#  'よそ': '他所',
#  'あつら': '誂',
#  'あかつき': '暁',
#  'がわ': '側',
#  'キモ': '肝',
#  'くたび': '草臥',
#  'ことわざ': '諺',
#  'せま': '狭',
#  'たわごと': '戯言',
#  'モンスタープレイヤーズ': 'ＭＰ',
#  'ブラン': '容疑者Ｂ',
#  'が': '我',
#  'なま': '生',
#  'あいたい': '相対',
#  'へ': '圧',
#  'かわ': '躱',
#  'せこ': '勢子',
#  'かし': '下賜',
#  'せいよんしゃくだま': '聖四灼玉',
#  'あいまみ': '相見',
#  'そぶ': '素振',
#  'おもちゃ': '鎧獣騎',
#  'ふたりめ': '二発目',
#  'しこくしょく': '紫黒色',
#  'あられ': '霰',
#  'ただ': '爛',
#  'ねぐら': '塒',
#  'アタッカー': 'ＤＰＳ',
#  'いただき': '頂',
#  'おおやけ': '公',
#  'わざわい': '禍',
#  'うず': '渦',
#  'うつつ': '現',
#  'たお': '嫋',
#  'たちわる': '質悪',
#  'きずもの': '瑕物',
#  'イベント': '決戦',
#  'ひび': '罅',
#  'オウゴンギンチャク': '黄金巾着',
#  'みき': '幹',
#  'なんびと': '何人',
#  'かくらん': '攪乱',
#  'うが': '穿',
#  'えぐ': '抉',
#  'く': '臭',
#  'のき': '軒',
#  'よしみ': '誼',
#  'ファーストアタック': '一番槍',
#  'うつ': '伝染',
#  'みずかめ': '水甕',
#  'ひときわ': '一際',
#  'あか': '赫',
#  'さんさん': '燦々'}

# %%
multi_rubi = {re.sub(r'\s', '', k): v for k, v in rubi.items() if len(v) > 1}
print(multi_rubi)
# Out:
# {}

# %%
response = None
if not len(multi_rubi) == 0:
    with open('resource/rubi_prompt.txt', 'r') as f:
        ruby_prompt = f.read()
        
    prompt = ruby_prompt + str(multi_rubi)
    message = fp.ProtocolMessage(role="user", content=prompt)
    response = await get_responses(api_key, [message])

# %%
if not len(multi_rubi) == 0 and 'response' in locals() and response is not None:
    dictionary = parse_gpt_json(response)
    dictionary.update(rubi)
    print(dictionary)
else:
    dictionary = rubi

# %%
# Dump the final dictionary to CN_TITLE/names.json
import json
with open(os.path.join('output', config['CN_TITLE'], 'names.json'), 'w') as f:
    json.dump(dictionary, f, ensure_ascii=False, indent=4)

# %%
def filter(entity, count):
    for name in dictionary.keys():
        if entity in name or name in entity:
            return False
    for name in dictionary.values():
        if entity in name or name in entity:
            return False
    return len(entity) > 1 and count > 1 and fix_repeated_chars(entity) == entity and has_kana(entity) 

entities = {entity: count for entity, count in entities.items() if filter(entity, count)}
entities = dict(sorted(entities.items(), key=lambda item: item[1], reverse=True))
names = partition_words(entities.keys(), 30)

names

# %%
example_sentences = find_example_sentences(flatten([list(s) for s in names]), book)
responses = []

with open('resource/namedetect_prompt_2.txt', 'r') as f:
    prompt_2 = f.read()

for name in names:
    name = sorted(list(name))
    prompt = ''
    for n in name:
        if n in example_sentences:
            sentence = example_sentences[n]
            if len(sentence) > 100:
                idx = sentence.find(n)
                sentence = sentence[idx - 50: idx + 50]
            prompt += n + '：' + sentence + '\n'
    prompt = prompt_2 + prompt + "\n\n----- 现在请回答日文名词，用中文解释"
    
    print(prompt)
    print('\n' + '#' * 80 + '\n')
    
    message = fp.ProtocolMessage(role="user", content=prompt)
    responses.append(await get_responses(api_key, [message]))
    print('\n' + '#' * 80 + '\n')

# %%
name_set = set().union(*names)
filtered_names = []
for response in responses:
    new_names = set()
    for line in response.split('\n'):
        line = line.strip()
        if "解释" in line:
            break
        if "：" in line or len(line.strip()) == 0:
            continue
        if line.startswith('- '):
            line = line[2:]
        word = find_first_non_consecutive_substring(line, name_set)
        if word is not None:
            new_names.add(word)
        else:
            new_names.add(line)
    if len(new_names) == 0:
        raise
    filtered_names += new_names

for i, (entity, count) in enumerate(entities.items()):
    if count > 20 and i < 10:  # Top 20 and count > 10
        for name in filtered_names:  # Not extending found names
            if name in entity:
                break
        else:
            filtered_names.append(entity)
            
filtered_names = partition_words(filtered_names, 30)
print(len(filtered_names))
filtered_names

# %%
with open('resource/namedetect_prompt_1.txt', 'r') as f:
    prompt_1 = f.read()
    
responses_ = []
for name in filtered_names:
    name = sorted(list(name))
    prompt = ''
    for n in name:
        if n in example_sentences:
            prompt += n + '：' + example_sentences[n] + '\n'
    prompt = prompt_1 + prompt
    print(prompt)
    message = fp.ProtocolMessage(role="user", content=prompt)
    responses_.append(await get_responses(api_key, [message]))
    print()

# %%
final_dictionary = {}
for response in responses_:
    final_dictionary.update(parse_gpt_json(response))
final_dictionary.update(dictionary)
to_delete = []
to_add = {}
for key, val in final_dictionary.items():
    if val.endswith('君') and key.endswith('さん'):
        to_delete.append(key)
        to_add[key[:-1]] = val[:-1]
    key_new, val_new = remove_common_suffix(key, val)
    if key_new != key:
        to_delete.append(key)
        to_add[key_new] = val_new
        
for key in to_delete:
    del final_dictionary[key]
for key, val in to_add.items():
    final_dictionary[key] = val

print(final_dictionary)

# %%
for keys in final_dictionary.keys():
    if toggle_kana(keys) in final_dictionary:
        if final_dictionary[keys] != final_dictionary[toggle_kana(keys)]:
            print(keys, final_dictionary[keys], final_dictionary[toggle_kana(keys)])
            if keys in dictionary:
                final_dictionary[keys] = dictionary[keys]
                final_dictionary[toggle_kana(keys)] = dictionary[keys]
            elif toggle_kana(keys) in dictionary:
                final_dictionary[keys] = dictionary[toggle_kana(keys)]
                final_dictionary[toggle_kana(keys)] = dictionary[toggle_kana(keys)]
            else:
                final_dictionary[keys] = final_dictionary[toggle_kana(keys)]
final_dictionary[config["JP_TITLE"]] = config["CN_TITLE"]

# %%
# Dump the final dictionary to CN_TITLE/names.json
import json
with open(os.path.join('output', config['CN_TITLE'], 'names.json'), 'w') as f:
    json.dump(final_dictionary, f, ensure_ascii=False, indent=4)
